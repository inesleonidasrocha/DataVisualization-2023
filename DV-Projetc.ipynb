# %%
import pandas as pd

# %%
apartamentos_2out22 = pd.read_excel('imovirtual_02OUT2022(apartamentos).xlsx')
apartamentos_2out22 = apartamentos_2out22.set_index('ID')
moradias_2out22 = pd.read_excel('imovirtual_02OUT2022(moradias).xlsx')
moradias_2out22 = moradias_2out22.set_index('ID')
quintas_herdades_2out22 = pd.read_excel('imovirtual_02OUT2022(quintas e herdades).xlsx')
quintas_herdades_2out22 = quintas_herdades_2out22.set_index('ID')

moradias_5nov22 = pd.read_excel('imovirtual_05NOV2022(moradias).xlsx')
moradias_5nov22 = moradias_5nov22.set_index('ID')
quintas_herdades_5nov22 = pd.read_excel('imovirtual_05NOV2022(Quintas e Herdades).xlsx')
quintas_herdades_5nov22 = quintas_herdades_5nov22.set_index('ID')

moradias_18mar23 = pd.read_csv('imovirtual_18MAR2023(moradias).csv', delimiter=';')
moradias_18mar23 = moradias_18mar23.set_index('Unnamed: 0')
apartamentos_18mar23 = pd.read_csv('imovirtual_18MAR2023(apartamentos).csv', delimiter=';')
apartamentos_18mar23 = apartamentos_18mar23.set_index('Unnamed: 0')
quintas_herdades_18mar23 = pd.read_csv('imovirtual_18MAR2023(quintas e herdades).csv', delimiter=';')
quintas_herdades_18mar23 = quintas_herdades_18mar23.set_index('Unnamed: 0')
terrenos_18mar23 = pd.read_csv('imovirtual_18MAR2023(terrenos).csv', delimiter=';')
terrenos_18mar23 = terrenos_18mar23.set_index('Unnamed: 0')

# %%
todos = pd.concat([apartamentos_2out22,moradias_2out22,quintas_herdades_2out22, moradias_5nov22,quintas_herdades_5nov22, moradias_18mar23, apartamentos_18mar23,quintas_herdades_18mar23,terrenos_18mar23], axis=0)

# %%
todos
# Out:
#               Tipo                                             Titulo  \
# 0      Apartamento   Apartamento T2 - Empreendimento Cerrado da Fonte
# 1      Apartamento      Apartamento TO ao Pólo Universitário do Porto
# 10     Apartamento                          Apartamento T4 para venda
# 100    Apartamento  APARTAMENTO T3 COM EXCELENTE EXPOSIÇÃO SOLAR E...
# 1000   Apartamento  Apt. T2 - Condomínio Fechado com varanda de 8 m2.
# ...            ...                                                ...
# 60499           []                    Terreno  Venda em Aradas,Aveiro
# 60500           []                           Terreno 2 Frentes, Lobão
# 60501           []                                      Venda Terreno
# 60502           []  Terreno com 25.510 m2 para venda em Almargem B...
# 60503           []                        Terreno em Relas / Amarante
#
#            Preço       Condição Quartos WC Dimensão m2      Terreno m2  \
# 0        400 000  Em construção      T2  2          80  sem informação
# 1        170 000          Usado      T0  2       35.87  sem informação
# 10       220 000          Usado      T4  2        99.3  sem informação
# 100      159 000          Usado      T3  2         110  sem informação
# 1000     333 000           Novo      T2  2          98  sem informação
# ...          ...            ...     ... ..         ...             ...
# 60499    210 000              -       -  -      150 €/        1 400 m²
# 60500    100 000              -       -  -       29 €/        3 500 m²
# 60501    550 000              -       -  -      110 €/        5 000 m²
# 60502  1 750 000              -       -  -       69 €/       25 510 m²
# 60503     40 000              -       -  -       87 €/          458 m²
#
#                                               Localidade  \
# 0                  São Domingos de Rana, Cascais, Lisboa
# 1                                        Paranhos, Porto
# 10                         Águas Livres, Amadora, Lisboa
# 100    União de Freguesias da cidade de Santarém, San...
# 1000                                     Paranhos, Porto
# ...                                                  ...
# 60499                                     Aradas, Aveiro
# 60500  Lobão, Gião, Louredo e Guisande, Santa Maria d...
# 60501  Sintra (Santa Maria e São Miguel, São Martinho...
# 60502  Almargem do Bispo, Pêro Pinheiro e Montelavar,...
# 60503  Amarante (São Gonçalo), Madalena, Cepelos e Ga...
#
#                                                     Link        Data
# 0      https://www.imovirtual.com/pt/anuncio/apartame...  2022-10-02
# 1      https://www.imovirtual.com/pt/anuncio/apartame...  2022-10-02
# 10     https://www.imovirtual.com/pt/anuncio/apartame...  2022-10-02
# 100    https://www.imovirtual.com/pt/anuncio/apartame...  2022-10-02
# 1000   https://www.imovirtual.com/pt/anuncio/apt-t2-c...  2022-10-02
# ...                                                  ...         ...
# 60499                                                 []  2023-03-19
# 60500                                                 []  2023-03-19
# 60501                                                 []  2023-03-19
# 60502                                                 []  2023-03-19
# 60503                                                 []  2023-03-19
#
# [389366 rows x 11 columns]
